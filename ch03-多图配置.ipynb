# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1.多图叠加

# %%
x = np.arange(-1, 1, 0.1)
y1 = np.exp(x)
y2 = np.exp(2*x)

# 分别画出不同的风格图
plt.plot(x, y1, color='r', linestyle='-', marker='^', linewidth=1)
plt.plot(x, y2, color='b', linestyle='-', marker='s', linewidth=1)

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 2.多个子图排列
#
# `figure()`函数可以帮助我们同时处理生成多个图，而`subplot()`函数则用来实现，在一个大图中，出现多个小的子图。比如，`subplot(1, 2, 1)`表示这是一个1行，2列布局的图（两个子图，在同一行，分居左右）
# 注：上下是两张图，合为1张的操作见下一小节

# %%
x = np.arange(-1, 1, 0.1)

y1 = np.exp(x)
y2 = np.exp(2*x)
y3 = np.exp(1.5*x)

#生成第一个图fig.1,并且处理fig.1
plt.figure(1)
# fig.1为一行两列布局，现在画第一个子图
plt.subplot(1, 2, 1)
plt.plot(x, y1, color='r', linestyle='-', marker='^', linewidth=1)
plt.xlabel('x')
plt.ylabel('y1')
plt.title('figure1_0')

#生成第二个图，并且处理fig.2
plt.figure(2)
plt.plot(x, y2, color='k', linestyle='-', marker='s', linewidth=1)
plt.xlabel('x')
plt.ylabel('y2')
plt.title('figure2')

#处理fig.1
plt.figure(1)
# 现在画第二个子图
plt.subplot(1, 2, 2)
plt.plot(x, y3, color='b', linestyle='-', marker='v', linewidth=1)
plt.xlabel('x')
plt.ylabel('y3')
plt.title('figure1_1')

plt.show()

# %% [markdown]
# ## 3.多子图合一

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 1, 0.1)

y1 = np.exp(x)
y2 = np.exp(1.5*x)
y3 = np.exp(2*x)

#生成第一个图fig.1,并且处理fig.1
plt.figure(1)
# fig.1为2x2布局，当前位置为1
plt.subplot(2, 2, 1)
plt.plot(x, y1, color='r', linestyle='-', marker='^', linewidth=1)
plt.xlabel('x')
plt.ylabel('y1')

# fig.1为2x2布局，当前位置为2
plt.subplot(2, 2, 2)
plt.plot(x, y2, color='k', linestyle='-', marker='s', linewidth=1)
plt.xlabel('x')
plt.ylabel('y2')


#处理fig.1
# 将fig.1转为2x1布局，当前位置为2，前两张图合并为一张图占据位置1
plt.subplot(2, 1, 2)
plt.plot(x, y3, color='b', linestyle='-', marker='v', linewidth=1)
plt.xlabel('x')
plt.ylabel('y3')

plt.show()
